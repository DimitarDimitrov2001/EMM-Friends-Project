# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("feature_engineered_data/df_final.csv")

# %%
def check_results(lines):
    """Print info, find false discoveries."""
    
    # Regex to capture conditions inside the IF statement, taking ANDs into account
    pattern = r"(IF|AND)([A-Za-z0-9_ ]+?)\s*(<=|>=|<|>|=)\s*([0-9.eE+-]+)"
    
    # go over each subgroup found
    for line in lines:
        
        # Extract all _/variable/operator/value groups
        conditions = re.findall(pattern, line.split("->")[0])
        proportions = []

        for _, var, op, val in conditions:
            var = var.strip()
            val = float(val)

            if op == "<=":
                cond = df[var] <= val
            elif op == ">=":
                cond = df[var] >= val
            elif op == "<":
                cond = df[var] < val
            elif op == ">":
                cond = df[var] > val
            elif op == "=":
                cond = df[var] == val
            else:
                continue

            prop = cond.sum() / 236
            proportions.append(prop)
#             print(f"{var} {op} {val} -> proportion = {prop:.3f}")
            
            
            # Compute descriptive info
            var_mean = df[var].mean()
            var_min = df[var].min()
            var_max = df[var].max()

            if abs(val - var_mean) / abs(var_mean) < 0.01:
                relation_to_mean = "equal to mean" # relative to mean
            elif val < var_mean:
                relation_to_mean = "below mean"
            else:
                relation_to_mean = "above mean"

            if val == var_min:
                relation_to_range = "equal to min"
            elif val == var_max:
                relation_to_range = "equal to max"
            elif val < var_min:
                relation_to_range = "below min"
            elif val > var_max:
                relation_to_range = "above max"
            else:
                relation_to_range = "within range"

            print(f"{var} {op} {val:.4f} -> proportion = {prop:.3f}")
            print(f"   ==> threshold is {relation_to_mean}, {relation_to_range}")
            
            

        if all(p >= 0.5 for p in proportions):
            print("False discovery (all >= 50%)")
            
        print("\n")

# %%
# Read rules from file max
with open("score_tstat_max.txt", "r") as f:
    max_lines = [l.strip() for l in f if l.strip()]

# %%
check_results(max_lines)
# Out:
# Central Perk <= 0.0537 -> proportion = 0.169
#    ==> threshold is below mean, within range
# exchanges_CHANDLER_JOEY <= 31.6667 -> proportion = 0.831
#    ==> threshold is above mean, within range
# exchanges_CHANDLER_PHOEBE <= 5.0000 -> proportion = 0.547
#    ==> threshold is below mean, within range
#
#
# Central Perk <= 0.0537 -> proportion = 0.169
#    ==> threshold is below mean, within range
# avg_words_per_line <= 10.5358 -> proportion = 0.665
#    ==> threshold is above mean, within range
# exchanges_RACHEL_CHANDLER <= 4.0000 -> proportion = 0.534
#    ==> threshold is below mean, within range
#
#
# Central Perk <= 0.0537 -> proportion = 0.169
#    ==> threshold is below mean, within range
# Main apartments <= 0.6667 -> proportion = 0.856
#    ==> threshold is above mean, within range
# exchanges_RACHEL_CHANDLER <= 4.0000 -> proportion = 0.534
#    ==> threshold is below mean, within range
#
#
# Central Perk <= 0.0537 -> proportion = 0.169
#    ==> threshold is below mean, within range
# exchanges_CHANDLER_JOEY <= 12.0000 -> proportion = 0.525
#    ==> threshold is below mean, within range
# exchanges_RACHEL_CHANDLER <= 4.0000 -> proportion = 0.534
#    ==> threshold is below mean, within range
#
#
# Central Perk <= 0.0537 -> proportion = 0.169
#    ==> threshold is below mean, within range
# exchanges_CHANDLER_JOEY <= 18.6667 -> proportion = 0.665
#    ==> threshold is above mean, within range
# exchanges_RACHEL_CHANDLER <= 4.0000 -> proportion = 0.534
#    ==> threshold is below mean, within range
#
#
# Central Perk <= 0.0537 -> proportion = 0.169
#    ==> threshold is below mean, within range
# exchanges_RACHEL_CHANDLER <= 4.0000 -> proportion = 0.534
#    ==> threshold is below mean, within range
# vocab_richness > 0.3775 -> proportion = 0.665
#    ==> threshold is below mean, within range
#
#
# Central Perk <= 0.0537 -> proportion = 0.169
#    ==> threshold is below mean, within range
# character_lines_ROSS > 0.1680 -> proportion = 0.335
#    ==> threshold is above mean, within range
# exchanges_CHANDLER_PHOEBE <= 7.0000 -> proportion = 0.686
#    ==> threshold is below mean, within range
#
#
# Central Perk <= 0.0537 -> proportion = 0.169
#    ==> threshold is below mean, within range
# exchanges_CHANDLER_PHOEBE <= 5.0000 -> proportion = 0.547
#    ==> threshold is below mean, within range
# vocab_richness > 0.3681 -> proportion = 0.831
#    ==> threshold is below mean, within range
#
#
# Central Perk <= 0.0537 -> proportion = 0.169
#    ==> threshold is below mean, within range
# exchanges_CHANDLER_PHOEBE <= 5.0000 -> proportion = 0.547
#    ==> threshold is below mean, within range
# exchanges_JOEY_PHOEBE > 1.0000 -> proportion = 0.784
#    ==> threshold is below mean, within range
#
#
# Central Perk <= 0.0537 -> proportion = 0.169
#    ==> threshold is below mean, within range
# Main apartments <= 0.6667 -> proportion = 0.856
#    ==> threshold is above mean, within range
# avg_words_per_line <= 11.0805 -> proportion = 0.831
#    ==> threshold is above mean, within range
#
#
# Central Perk <= 0.0537 -> proportion = 0.169
#    ==> threshold is below mean, within range
# emotion_joy > 0.1135 -> proportion = 0.831
#    ==> threshold is below mean, within range
# exchanges_MONICA_CHANDLER > 4.0000 -> proportion = 0.792
#    ==> threshold is below mean, within range
#
#
# Central Perk <= 0.0537 -> proportion = 0.169
#    ==> threshold is below mean, within range
# exchanges_CHANDLER_JOEY <= 12.0000 -> proportion = 0.525
#    ==> threshold is below mean, within range
# exchanges_MONICA_PHOEBE <= 13.6667 -> proportion = 0.665
#    ==> threshold is above mean, within range
#
#
# Central Perk <= 0.0537 -> proportion = 0.169
#    ==> threshold is below mean, within range
# exchanges_CHANDLER_PHOEBE <= 5.0000 -> proportion = 0.547
#    ==> threshold is below mean, within range
# exchanges_MONICA_CHANDLER > 4.0000 -> proportion = 0.792
#    ==> threshold is below mean, within range
#
#
# Central Perk <= 0.0537 -> proportion = 0.169
#    ==> threshold is below mean, within range
# Main apartments <= 0.5333 -> proportion = 0.678
#    ==> threshold is above mean, within range
# exchanges_RACHEL_CHANDLER <= 4.0000 -> proportion = 0.534
#    ==> threshold is below mean, within range
#
#
# Central Perk <= 0.0537 -> proportion = 0.169
#    ==> threshold is below mean, within range
# emotion_joy > 0.1135 -> proportion = 0.831
#    ==> threshold is below mean, within range
# sentiment_compound <= 0.1472 -> proportion = 0.500
#    ==> threshold is below mean, within range
#
#
# Central Perk <= 0.0537 -> proportion = 0.169
#    ==> threshold is below mean, within range
# exchanges_RACHEL_CHANDLER <= 4.0000 -> proportion = 0.534
#    ==> threshold is below mean, within range
# vocab_richness > 0.3681 -> proportion = 0.831
#    ==> threshold is below mean, within range
#
#
# Central Perk <= 0.0537 -> proportion = 0.169
#    ==> threshold is below mean, within range
# Main apartments <= 0.6667 -> proportion = 0.856
#    ==> threshold is above mean, within range
# avg_words_per_line <= 10.5358 -> proportion = 0.665
#    ==> threshold is above mean, within range
#
#
# Central Perk <= 0.0537 -> proportion = 0.169
#    ==> threshold is below mean, within range
# character_lines_JOEY <= 0.1492 -> proportion = 0.665
#    ==> threshold is above mean, within range
# exchanges_RACHEL_CHANDLER <= 4.0000 -> proportion = 0.534
#    ==> threshold is below mean, within range
#
#
# Central Perk <= 0.0537 -> proportion = 0.169
#    ==> threshold is below mean, within range
# exchanges_MONICA_CHANDLER > 4.0000 -> proportion = 0.792
#    ==> threshold is below mean, within range
# exchanges_RACHEL_CHANDLER <= 4.0000 -> proportion = 0.534
#    ==> threshold is below mean, within range
#
#
# Central Perk <= 0.0537 -> proportion = 0.169
#    ==> threshold is below mean, within range
# exchanges_CHANDLER_JOEY <= 31.6667 -> proportion = 0.831
#    ==> threshold is above mean, within range
# exchanges_RACHEL_CHANDLER <= 4.0000 -> proportion = 0.534
#    ==> threshold is below mean, within range
#
#
# Central Perk <= 0.0537 -> proportion = 0.169
#    ==> threshold is below mean, within range
# emotion_joy > 0.1135 -> proportion = 0.831
#    ==> threshold is below mean, within range
# sentiment_compound <= 0.1641 -> proportion = 0.665
#    ==> threshold is above mean, within range
#
#
# Central Perk <= 0.0537 -> proportion = 0.169
#    ==> threshold is below mean, within range
# emotion_joy > 0.1135 -> proportion = 0.831
#    ==> threshold is below mean, within range
# exchanges_JOEY_PHOEBE > 3.0000 -> proportion = 0.614
#    ==> threshold is below mean, within range
#
#
# Central Perk <= 0.0537 -> proportion = 0.169
#    ==> threshold is below mean, within range
# Main apartments <= 0.6667 -> proportion = 0.856
#    ==> threshold is above mean, within range
# exchanges_MONICA_RACHEL <= 23.0000 -> proportion = 0.839
#    ==> threshold is above mean, within range
#
#
# Central Perk <= 0.0537 -> proportion = 0.169
#    ==> threshold is below mean, within range
# character_lines_OTHER > 0.1208 -> proportion = 0.665
#    ==> threshold is below mean, within range
# exchanges_CHANDLER_JOEY <= 12.0000 -> proportion = 0.525
#    ==> threshold is below mean, within range
#
#
# Central Perk <= 0.0537 -> proportion = 0.169
#    ==> threshold is below mean, within range
# character_lines_ROSS > 0.1680 -> proportion = 0.335
#    ==> threshold is above mean, within range
# exchanges_CHANDLER_PHOEBE <= 5.0000 -> proportion = 0.547
#    ==> threshold is below mean, within range

# %%
# Read rules from file min
with open("score_tstat_min.txt", "r") as f:
    min_lines = [l.strip() for l in f if l.strip()]

# %%
check_results(min_lines)
# Out:
# exchanges_CHANDLER_JOEY <= 31.6667 -> proportion = 0.831
#    ==> threshold is above mean, within range
# exchanges_MONICA_CHANDLER <= 4.0000 -> proportion = 0.208
#    ==> threshold is below mean, within range
# exchanges_ROSS_CHANDLER > 7.0000 -> proportion = 0.470
#    ==> threshold is below mean, within range
#
#
# Main apartments <= 0.4667 -> proportion = 0.508
#    ==> threshold is below mean, within range
# exchanges_MONICA_CHANDLER <= 4.0000 -> proportion = 0.208
#    ==> threshold is below mean, within range
# exchanges_ROSS_CHANDLER > 7.0000 -> proportion = 0.470
#    ==> threshold is below mean, within range
#
#
# exchanges_CHANDLER_JOEY <= 18.6667 -> proportion = 0.665
#    ==> threshold is above mean, within range
# exchanges_MONICA_CHANDLER <= 4.0000 -> proportion = 0.208
#    ==> threshold is below mean, within range
# exchanges_ROSS_CHANDLER > 7.0000 -> proportion = 0.470
#    ==> threshold is below mean, within range
#
#
# Main apartments <= 0.5333 -> proportion = 0.678
#    ==> threshold is above mean, within range
# exchanges_MONICA_CHANDLER <= 4.0000 -> proportion = 0.208
#    ==> threshold is below mean, within range
# exchanges_ROSS_CHANDLER > 7.0000 -> proportion = 0.470
#    ==> threshold is below mean, within range
#
#
# Main apartments <= 0.4667 -> proportion = 0.508
#    ==> threshold is below mean, within range
# exchanges_MONICA_CHANDLER <= 4.0000 -> proportion = 0.208
#    ==> threshold is below mean, within range
# exchanges_ROSS_CHANDLER > 4.0000 -> proportion = 0.623
#    ==> threshold is below mean, within range
#
#
# Central Perk > 0.2308 -> proportion = 0.301
#    ==> threshold is above mean, within range
# character_lines_JOEY <= 0.1492 -> proportion = 0.665
#    ==> threshold is above mean, within range
# vocab_richness > 0.3865 -> proportion = 0.500
#    ==> threshold is equal to mean, within range
#
#
# character_lines_OTHER > 0.1208 -> proportion = 0.665
#    ==> threshold is below mean, within range
# exchanges_MONICA_CHANDLER <= 4.0000 -> proportion = 0.208
#    ==> threshold is below mean, within range
# exchanges_ROSS_CHANDLER > 11.0000 -> proportion = 0.322
#    ==> threshold is above mean, within range
#
#
# Central Perk > 0.1667 -> proportion = 0.470
#    ==> threshold is below mean, within range
# character_lines_JOEY <= 0.1292 -> proportion = 0.504
#    ==> threshold is below mean, within range
# vocab_richness > 0.3865 -> proportion = 0.500
#    ==> threshold is equal to mean, within range
#
#
# character_lines_OTHER > 0.1208 -> proportion = 0.665
#    ==> threshold is below mean, within range
# exchanges_MONICA_CHANDLER <= 4.0000 -> proportion = 0.208
#    ==> threshold is below mean, within range
# exchanges_ROSS_CHANDLER > 7.0000 -> proportion = 0.470
#    ==> threshold is below mean, within range
#
#
# Central Perk > 0.1667 -> proportion = 0.470
#    ==> threshold is below mean, within range
# avg_words_per_line > 10.5358 -> proportion = 0.335
#    ==> threshold is above mean, within range
# vocab_richness > 0.3865 -> proportion = 0.500
#    ==> threshold is equal to mean, within range
#
#
# Central Perk > 0.2308 -> proportion = 0.301
#    ==> threshold is above mean, within range
# character_lines_JOEY <= 0.1292 -> proportion = 0.504
#    ==> threshold is below mean, within range
# vocab_richness > 0.3865 -> proportion = 0.500
#    ==> threshold is equal to mean, within range
#
#
# Central Perk > 0.1667 -> proportion = 0.470
#    ==> threshold is below mean, within range
# character_lines_MONICA > 0.1559 -> proportion = 0.335
#    ==> threshold is above mean, within range
# exchanges_RACHEL_ROSS <= 12.0000 -> proportion = 0.504
#    ==> threshold is below mean, within range
#
#
# Main apartments <= 0.5333 -> proportion = 0.678
#    ==> threshold is above mean, within range
# exchanges_MONICA_CHANDLER <= 4.0000 -> proportion = 0.208
#    ==> threshold is below mean, within range
# exchanges_ROSS_CHANDLER > 11.0000 -> proportion = 0.322
#    ==> threshold is above mean, within range
#
#
# Central Perk > 0.1667 -> proportion = 0.470
#    ==> threshold is below mean, within range
# emotion_joy <= 0.2145 -> proportion = 0.831
#    ==> threshold is above mean, within range
# exchanges_MONICA_RACHEL > 23.0000 -> proportion = 0.161
#    ==> threshold is above mean, within range
#
#
# Central Perk > 0.1667 -> proportion = 0.470
#    ==> threshold is below mean, within range
# avg_words_per_line > 10.5358 -> proportion = 0.335
#    ==> threshold is above mean, within range
# exchanges_RACHEL_CHANDLER <= 4.0000 -> proportion = 0.534
#    ==> threshold is below mean, within range
#
#
# Central Perk > 0.2308 -> proportion = 0.301
#    ==> threshold is above mean, within range
# character_lines_JOEY <= 0.1492 -> proportion = 0.665
#    ==> threshold is above mean, within range
# exchanges_RACHEL_ROSS <= 12.0000 -> proportion = 0.504
#    ==> threshold is below mean, within range
#
#
# emotion_joy <= 0.1443 -> proportion = 0.335
#    ==> threshold is below mean, within range
# exchanges_MONICA_ROSS > 9.0000 -> proportion = 0.326
#    ==> threshold is above mean, within range
# exchanges_RACHEL_JOEY > 3.0000 -> proportion = 0.610
#    ==> threshold is below mean, within range
#
#
# Jobs > 0.2308 -> proportion = 0.140
#    ==> threshold is above mean, within range
# emotion_surprise <= 0.1836 -> proportion = 0.665
#    ==> threshold is above mean, within range
# sentiment_neu <= 0.8081 -> proportion = 0.831
#    ==> threshold is above mean, within range
#
#
# emotion_surprise <= 0.1990 -> proportion = 0.831
#    ==> threshold is above mean, within range
# exchanges_MONICA_CHANDLER <= 4.0000 -> proportion = 0.208
#    ==> threshold is below mean, within range
# exchanges_ROSS_CHANDLER > 7.0000 -> proportion = 0.470
#    ==> threshold is below mean, within range
#
#
# Central Perk > 0.1667 -> proportion = 0.470
#    ==> threshold is below mean, within range
# emotion_anger <= 0.0793 -> proportion = 0.665
#    ==> threshold is above mean, within range
# exchanges_ROSS_JOEY > 2.0000 -> proportion = 0.788
#    ==> threshold is below mean, within range
#
#
# Central Perk > 0.2308 -> proportion = 0.301
#    ==> threshold is above mean, within range
# character_lines_OTHER > 0.1208 -> proportion = 0.665
#    ==> threshold is below mean, within range
# vocab_richness > 0.3975 -> proportion = 0.335
#    ==> threshold is above mean, within range
#
#
# character_lines_JOEY <= 0.1492 -> proportion = 0.665
#    ==> threshold is above mean, within range
# exchanges_MONICA_CHANDLER <= 4.0000 -> proportion = 0.208
#    ==> threshold is below mean, within range
# exchanges_ROSS_CHANDLER > 7.0000 -> proportion = 0.470
#    ==> threshold is below mean, within range
#
#
# avg_words_per_line > 10.5358 -> proportion = 0.335
#    ==> threshold is above mean, within range
# character_lines_CHANDLER <= 0.1205 -> proportion = 0.335
#    ==> threshold is below mean, within range
# exchanges_ROSS_PHOEBE > 2.0000 -> proportion = 0.661
#    ==> threshold is below mean, within range
#
#
# exchanges_MONICA_CHANDLER <= 4.0000 -> proportion = 0.208
#    ==> threshold is below mean, within range
# exchanges_RACHEL_PHOEBE <= 20.8333 -> proportion = 0.831
#    ==> threshold is above mean, within range
# exchanges_ROSS_CHANDLER > 7.0000 -> proportion = 0.470
#    ==> threshold is below mean, within range
#
#
# Central Perk > 0.1667 -> proportion = 0.470
#    ==> threshold is below mean, within range
# character_lines_MONICA > 0.1383 -> proportion = 0.500
#    ==> threshold is below mean, within range
# humor > 0.6716 -> proportion = 0.335
#    ==> threshold is above mean, within range
