# %%
import numpy as np
import pandas as pd
import pysubgroup as ps

# %% [markdown]
# # pysubgroup example (not useful for us, see custom implementation)

# %%
import pysubgroup as ps

from pysubgroup.datasets import get_titanic_data
data = get_titanic_data()

target = ps.BinaryTarget ('Survived', True)
searchspace = ps.create_selectors(data, ignore=['Survived'])
task = ps.SubgroupDiscoveryTask (
    data,
    target,
    searchspace,
    result_set_size=5,
    depth=2,
    qf=ps.WRAccQF())
result = ps.BeamSearch().execute(task)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 152                                   Meo, Mr. Alfonzo    male  55.5      0
# 153                    van Billiard, Mr. Austin Blyler    male  40.5      0
# 154                              Olsen, Mr. Ole Martin    male   NaN      0
# 155                        Williams, Mr. Charles Duane    male  51.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 151      0            113776  66.6000    C2        S
# 152      0        A.5. 11206   8.0500   NaN        S
# 153      2          A/5. 851  14.5000   NaN        S
# 154      0         Fa 265302   7.3125   NaN        S
# 155      1          PC 17597  61.3792   NaN        C
#
# [156 rows x 12 columns]

# %%
print(result.to_dataframe())
# Out:
#     quality                          subgroup  size_sg  size_dataset  \
# 0  0.132150                     Sex=='female'       56           156
# 1  0.101331        Parch==0 AND Sex=='female'       41           156
# 2  0.079142    Sex=='female' AND SibSp: [0:1[       25           156
# 3  0.077663  Cabin.isnull() AND Sex=='female'       43           156
# 4  0.071746   Embarked=='S' AND Sex=='female'       37           156
#
#    positives_sg  positives_dataset  size_complement  relative_size_sg  \
# 0            40                 54              100          0.358974
# 1            30                 54              115          0.262821
# 2            21                 54              131          0.160256
# 3            27                 54              113          0.275641
# 4            24                 54              119          0.237179
#
#    relative_size_complement  coverage_sg  coverage_complement  \
# 0                  0.641026     0.740741             0.259259
# 1                  0.737179     0.555556             0.444444
# 2                  0.839744     0.388889             0.611111
# 3                  0.724359     0.500000             0.500000
# 4                  0.762821     0.444444             0.555556
#
#    target_share_sg  target_share_complement  target_share_dataset      lift
# 0         0.714286                 0.140000              0.346154  2.063492
# 1         0.731707                 0.208696              0.346154  2.113821
# 2         0.840000                 0.251908              0.346154  2.426667
# 3         0.627907                 0.238938              0.346154  1.813953
# 4         0.648649                 0.252101              0.346154  1.873874

# %% [markdown]
# # pysubgroup tinkering (not useful for us, see custom implementation)

# %%
import pysubgroup as ps

data = pd.read_csv("crop_yield.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pysubgroup as ps
# ----> 3 data = pd.read_csv("crop_yield.csv")
#
# File ~/.local/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.local/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/.local/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/.local/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/.local/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'crop_yield.csv'

# %%
data

# %%
data["target"] = data["Yield"] > np.quantile(data["Yield"], 0.99)

# %%
data

# %%
target = ps.BinaryTarget("target", True)
searchspace = ps.create_selectors(data[["Crop", "Crop_Year", "Season", "State", "Area", "Annual_Rainfall", "Fertilizer", "Pesticide"]])
task = ps.SubgroupDiscoveryTask (
    data,
    target,
    searchspace,
    result_set_size=10,
    depth=10,
    qf=ps.WRAccQF())

# %%
result = ps.BeamSearch().execute(task)
print(result.to_dataframe())

# %% [markdown]
# # Custom implementation

# %%
"""
Subgroup Discovery using Beam Search (Python)

This file contains a flexible implementation of subgroup discovery using beam search.
Features:
- Handles categorical and numeric attributes (numeric discretization via quantile thresholds)
- Beam search (width k) across conjunctions of attribute tests
- Supports binary or continuous target variable
- Configurable scoring functions: WRAcc (default for classification), precision, recall, F1, or custom callables
- Support for min_support and max_depth (max number of conditions per subgroup)
- Pretty printing + example usage on synthetic data

How to use:
- Import the SubgroupDiscovery class and call fit() with a pandas DataFrame and target column.

"""

from __future__ import annotations
from dataclasses import dataclass
from typing import Any, Callable, Dict, List, Tuple, Union
import pandas as pd
import numpy as np

Condition = Tuple[str, str, Any]  # (feature, operator, value)
Pattern = Tuple[Condition, ...]


@dataclass
class Subgroup:
    pattern: Pattern
    coverage: int
    target_stat: float  # mean target (continuous) or positives (discrete)
    score: float

    def __str__(self) -> str:
        conds = [f"{f} {op} {v}" for (f, op, v) in self.pattern]
        return f"IF {' AND '.join(conds)} -> coverage={self.coverage}, target_stat={self.target_stat:.4f}, score={self.score:.4f}"


class SubgroupDiscovery:
    def __init__(
        self,
        beam_width: int = 10,
        max_depth: int = 3,
        min_support: Union[int, float] = 0.05,
        numeric_thresholds: int = 5,
        scoring: Union[str, Callable[[int, float, int, float], float]] = "mean_diff_c",
        target_type: str = "continuous",  # "binary" or "continuous"
        target_positive: Any = 1,
        verbose: bool = False,
    ) -> None:
        """
        Parameters
        ----------
        beam_width: int
            Number of patterns to keep at each level of the beam.
        max_depth: int
            Maximum number of conditions in a pattern.
        min_support: int or float
            Minimum support for a pattern. If float between 0 and 1 -> fraction of records.
        numeric_thresholds: int
            Number of quantile-based thresholds to generate for numeric attributes.
        scoring: str or callable
            'wracc', 'precision', 'recall', 'f1' for binary target;
            or a custom callable with signature (n_cover, target_stat, n_total, global_stat) -> score
        target_type: str
            'binary' for classification, 'continuous' for regression-style subgroup discovery
        target_positive: value considered as positive class if binary
        verbose: bool
            Print progress messages.
        """
        self.beam_width = beam_width
        self.max_depth = max_depth
        self.min_support = min_support
        self.numeric_thresholds = numeric_thresholds
        self.verbose = verbose
        self.target_type = target_type
        self.target_positive = target_positive

        if isinstance(scoring, str):
            self.scoring_name = scoring
            if target_type == "binary":
                if scoring == "wracc":
                    self.scoring = self._score_wracc
                elif scoring == "precision":
                    self.scoring = self._score_precision
                elif scoring == "recall":
                    self.scoring = self._score_recall
                elif scoring == "f1":
                    self.scoring = self._score_f1
                else:
                    raise ValueError(f"Unknown scoring string for binary target: {scoring}")
            elif target_type == "continuous":
                if scoring == "mean_diff":
                    self.scoring = self._score_mean_diff
                elif scoring == "mean_diff_c":
                    self.scoring = self._score_mean_diff_c
                else:
                    raise ValueError(f"Unknown scoring string for continuous target: {scoring}")
            else:
                raise ValueError("target_type must be 'binary' or 'continuous'")
        else:
            self.scoring_name = "custom"
            self.scoring = scoring

        # internals
        self.feature_types: Dict[str, str] = {}
        self.thresholds: Dict[str, List[float]] = {}
        self.best_subgroups: List[Subgroup] = []

    # ----------------------- scoring functions -----------------------
    def _score_wracc(self, n_cover: int, n_pos: int, n_total: int, n_pos_total: int) -> float:
        if n_cover == 0:
            return 0.0
        p_global = n_pos_total / n_total
        p_sub = n_pos / n_cover
        coverage_frac = n_cover / n_total
        return coverage_frac * (p_sub - p_global)

    def _score_precision(self, n_cover: int, n_pos: int, n_total: int, n_pos_total: int) -> float:
        if n_cover == 0:
            return 0.0
        return n_pos / n_cover

    def _score_recall(self, n_cover: int, n_pos: int, n_total: int, n_pos_total: int) -> float:
        if n_pos_total == 0:
            return 0.0
        return n_pos / n_pos_total

    def _score_f1(self, n_cover: int, n_pos: int, n_total: int, n_pos_total: int) -> float:
        prec = self._score_precision(n_cover, n_pos, n_total, n_pos_total)
        rec = self._score_recall(n_cover, n_pos, n_total, n_pos_total)
        if prec + rec == 0:
            return 0.0
        return 2 * (prec * rec) / (prec + rec)

    def _score_mean_diff(self, n_cover: int, mean_sub: float, n_total: int, mean_global: float) -> float:
        if n_cover == 0:
            return 0.0
        return abs(mean_sub - mean_global)
    
    def _score_mean_diff_c(self, n_cover: int, mean_sub: float, n_total: int, mean_global: float) -> float:
        if n_cover == 0:
            return 0.0
        # difference in means, scaled by coverage fraction
        coverage_frac = n_cover / n_total
        return coverage_frac * abs(mean_sub - mean_global)

    # ----------------------- helpers -----------------------
    def _detect_feature_types(self, df: pd.DataFrame, exclude: str) -> None:
        for col in df.columns:
            if col == exclude:
                continue
            if pd.api.types.is_numeric_dtype(df[col]):
                self.feature_types[col] = "numeric"
            else:
                self.feature_types[col] = "categorical"

    def _generate_thresholds(self, df: pd.DataFrame) -> None:
        self.thresholds = {}
        for f, t in self.feature_types.items():
            if t == "numeric":
                vals = df[f].dropna().unique()
                if len(vals) <= self.numeric_thresholds:
                    thr = sorted(vals)
                else:
                    # quantile-based thresholds
                    qs = np.linspace(0, 1, self.numeric_thresholds + 2)[1:-1]
                    thr = sorted(pd.Series(df[f].dropna()).quantile(qs).unique())
                self.thresholds[f] = thr
            else:
                self.thresholds[f] = sorted(df[f].dropna().unique())

    def _apply_condition(self, df: pd.DataFrame, cond: Condition) -> pd.Series:
        f, op, v = cond
        if op == "==":
            return df[f] == v
        elif op == "<=":
            return df[f] <= v
        elif op == ">":
            return df[f] > v
        else:
            raise ValueError(f"Unknown operator: {op}")

    def _apply_pattern_mask(self, df: pd.DataFrame, pattern: Pattern) -> np.ndarray:
        if len(pattern) == 0:
            return np.ones(len(df), dtype=bool)
        masks = [self._apply_condition(df, cond) for cond in pattern]
        return np.logical_and.reduce(masks)

    def _pattern_to_str(self, pattern: Pattern) -> str:
        return " AND ".join([f"{f}{op}{v}" for (f, op, v) in pattern])

    # ----------------------- beam search core -----------------------
    def fit(self, df: pd.DataFrame, target: str, top_k: int = 10) -> List[Subgroup]:
        """
        Run beam search to find top_k subgroups.

        Returns list of Subgroup objects sorted by score descending.
        """
        df = df.copy()
        n_total = len(df)
        if n_total == 0:
            return []

        # interpret min_support
        if 0 < self.min_support < 1:
            min_sup_count = max(1, int(np.ceil(self.min_support * n_total)))
        else:
            min_sup_count = int(self.min_support)

        # globals
        self._detect_feature_types(df, exclude=target)
        self._generate_thresholds(df)

        if self.target_type == "binary":
            global_stat = int((df[target] == self.target_positive).sum())
        else:  # continuous
            global_stat = df[target].mean()

        if self.verbose:
            print(f"n_total={n_total}, global_stat={global_stat}, min_sup_count={min_sup_count}")

        # initial candidates: single conditions
        initial_candidates: List[Pattern] = []
        for f, t in self.feature_types.items():
            for val in self.thresholds[f]:
                if t == "numeric":
                    initial_candidates.append(((f, "<=", float(val)),))
                    initial_candidates.append(((f, ">", float(val)),))
                else:
                    initial_candidates.append(((f, "==", val),))

        # evaluate initial candidates and form first beam
        scored: List[Subgroup] = []
        for p in initial_candidates:
            mask = self._apply_pattern_mask(df, p)
            n_cover = int(mask.sum())
            if n_cover < min_sup_count:
                continue
            if self.target_type == "binary":
                n_pos = int(((df.loc[mask, target]) == self.target_positive).sum())
                stat = n_pos
                score = self.scoring(n_cover, n_pos, n_total, global_stat)
            else:
                mean_sub = df.loc[mask, target].mean()
                stat = mean_sub
                score = self.scoring(n_cover, mean_sub, n_total, global_stat)
            scored.append(Subgroup(p, n_cover, stat, score))

        # sort beam by score
        scored.sort(key=lambda s: s.score, reverse=True)
        beam = [s.pattern for s in scored[: self.beam_width]]
        self.best_subgroups = scored[:top_k]

        
        # iterative expansion
        for depth in range(2, self.max_depth + 1):
            if len(beam) == 0:
                break

            candidates: List[Pattern] = []
            seen_pattern_keys: set = set()

            for pattern in beam:
                used_features = {c[0] for c in pattern}
                for f, t in self.feature_types.items():
                    if f in used_features:
                        continue
                    ops = ("<=", ">") if t == "numeric" else ("==",)
                    for val in self.thresholds[f]:
                        for op in ops:
                            v = float(val) if t == "numeric" else val
                            new_pat = tuple(list(pattern) + [(f, op, v)])
                            
                            new_pat_sorted = tuple(sorted(new_pat, key=lambda x: (x[0], x[1], str(x[2]))))
            
                            key = frozenset(new_pat_sorted)
            
                            if key in seen_pattern_keys:
                                continue
            
                            seen_pattern_keys.add(key)
                            candidates.append(new_pat_sorted)

            # evaluate candidates and pick top beam_width
            scored_next: List[Subgroup] = []
            for p in candidates:
                mask = self._apply_pattern_mask(df, p)
                n_cover = int(mask.sum())
                if n_cover < min_sup_count:
                    continue
                if self.target_type == "binary":
                    n_pos = int(((df.loc[mask, target]) == self.target_positive).sum())
                    stat = n_pos
                    score = self.scoring(n_cover, n_pos, n_total, global_stat)
                else:
                    mean_sub = df.loc[mask, target].mean()
                    stat = mean_sub
                    score = self.scoring(n_cover, mean_sub, n_total, global_stat)
                scored_next.append(Subgroup(p, n_cover, stat, score))

            scored_next.sort(key=lambda s: s.score, reverse=True)
            beam = [s.pattern for s in scored_next[: self.beam_width]]

            combined = self.best_subgroups + scored_next
            combined.sort(key=lambda s: s.score, reverse=True)
            self.best_subgroups = combined[:top_k]

        self.best_subgroups.sort(key=lambda s: s.score, reverse=True)
        return self.best_subgroups

# %%
data = pd.read_csv("crop_yield.csv")
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data = pd.read_csv("crop_yield.csv")
#       2 data.head()
#
# File ~/.local/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.local/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/.local/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/.local/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/.local/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'crop_yield.csv'

# %%
sd = SubgroupDiscovery(beam_width=8, max_depth=4, min_support=0.01, numeric_thresholds=5, scoring="corr", target_type="continuous", verbose=True)
top = sd.fit(data[["Crop", "Crop_Year", "Season", "State", "Area", "Annual_Rainfall", "Fertilizer", "Pesticide", "Yield"]], target="Yield", top_k=10)

# %%
for s in top:
    print(s)

# %% [markdown]
# # Application on our data

# %%
df = pd.read_csv("feature_engineered_data/df_final.csv")
df.head()
# Out:
#    season  episode                                            title  \
# 0       1        1  The One Where Monica Gets a Roommate: The Pilot
# 1       1        2             The One with the Sonogram at the End
# 2       1        3                           The One with the Thumb
# 3       1        4               The One with George Stephanopoulos
# 4       1        5   The One with the East German Laundry Detergent
#
#                                       episode_script  \
# 0  [SCENE NOTE: Scene: Central Perk, Chandler, Jo...
# 1  [SCENE NOTE: Scene Central Perk, everyone's th...
# 2  [SCENE NOTE: Scene: Central Perk, everyone but...
# 3  [SCENE NOTE: Scene: Central Perk, everyone is ...
# 4  [SCENE NOTE: Scene: Central Perk, all six are ...
#
#                                 episode_script_clean  avg_words_per_line  \
# 0  [SCENE NOTE: Scene: Central Perk, Chandler, Jo...           11.026667
# 1  [SCENE NOTE: Scene Central Perk, everyone's th...            9.572016
# 2  [SCENE NOTE: Scene: Central Perk, everyone but...            9.104651
# 3  [SCENE NOTE: Scene: Central Perk, everyone is ...            9.464286
# 4  [SCENE NOTE: Scene: Central Perk, all six are ...           10.268908
#
#    vocab_richness  character_lines_MONICA  character_lines_RACHEL  \
# 0        0.394800                0.243333                0.163333
# 1        0.448839                0.115226                0.156379
# 2        0.442316                0.201550                0.100775
# 3        0.459958                0.190476                0.170635
# 4        0.392799                0.138655                0.155462
#
#    character_lines_ROSS  ...  Central Perk  City spaces  Hallways  Hospitals  \
# 0              0.163333  ...      0.250000     0.000000       0.0   0.000000
# 1              0.259259  ...      0.181818     0.000000       0.0   0.272727
# 2              0.127907  ...      0.333333     0.133333       0.0   0.000000
# 3              0.158730  ...      0.187500     0.187500       0.0   0.250000
# 4              0.168067  ...      0.375000     0.187500       0.0   0.000000
#
#        Jobs  Main apartments  Other lodging  Social Life  Transport  stars
# 0  0.083333         0.500000            0.0     0.083333   0.083333    8.3
# 1  0.272727         0.272727            0.0     0.000000   0.000000    8.1
# 2  0.200000         0.266667            0.0     0.066667   0.000000    8.2
# 3  0.000000         0.375000            0.0     0.000000   0.000000    8.1
# 4  0.000000         0.125000            0.0     0.312500   0.000000    8.5
#
# [5 rows x 42 columns]

# %%
df.columns
# Out:
# Index(['season', 'episode', 'title', 'episode_script', 'episode_script_clean',
#        'avg_words_per_line', 'vocab_richness', 'character_lines_MONICA',
#        'character_lines_RACHEL', 'character_lines_ROSS',
#        'character_lines_CHANDLER', 'character_lines_JOEY',
#        'character_lines_PHOEBE', 'character_lines_OTHER', 'emotion_joy',
#        'emotion_sadness', 'emotion_anger', 'emotion_fear', 'emotion_surprise',
#        'emotion_disgust', 'emotion_neutral', 'sentiment_neg', 'sentiment_neu',
#        'sentiment_pos', 'sentiment_compound', 'sentiment_trajectory_slope',
#        'humor', 'exchanges_JOEY_CHANDLER', 'exchanges_RACHEL_MONICA',
#        'exchanges_ROSS_RACHEL', 'exchanges_MONICA_CHANDLER',
#        'exchanges_PHOEBE_JOEY', 'Central Perk', 'City spaces', 'Hallways',
#        'Hospitals', 'Jobs', 'Main apartments', 'Other lodging', 'Social Life',
#        'Transport', 'stars'],
#       dtype='object')

# %%
subgroup_descriptors = ["avg_words_per_line", "vocab_richness", 
                                 "character_lines_MONICA", 'character_lines_RACHEL', 'character_lines_ROSS', 'character_lines_CHANDLER', 
                                 'character_lines_JOEY', 'character_lines_PHOEBE', 'character_lines_OTHER',
                                 'emotion_joy', 'emotion_sadness', 'emotion_anger', 'emotion_fear', 'emotion_surprise', 'emotion_disgust', 'emotion_neutral',
                                 'sentiment_neg', 'sentiment_neu', 'sentiment_pos', 'sentiment_compound', 'sentiment_trajectory_slope',
                                 'humor',
                                 'exchanges_JOEY_CHANDLER', 'exchanges_RACHEL_MONICA', 'exchanges_ROSS_RACHEL', 'exchanges_MONICA_CHANDLER', 'exchanges_PHOEBE_JOEY',
                                 'Central Perk', 'City spaces', 'Hallways', 'Hospitals', 'Jobs', 'Main apartments', 'Other lodging', 'Social Life', 'Transport']

descriptors_and_target = subgroup_descriptors
descriptors_and_target.append("stars")

# %% [markdown]
# ## Scored by mean difference scaled by coverage

# %%
sd = SubgroupDiscovery(beam_width=500, max_depth=4, min_support=0, numeric_thresholds=5, scoring="mean_diff_c", target_type="continuous", verbose=True)
top = sd.fit(df[descriptors_and_target], target="stars", top_k=15)
# Out:
# n_total=236, global_stat=8.458898305084746, min_sup_count=0

# %%
for s in top:
    print(s)
    print("\n")
# Out:
# IF Central Perk > 0.05366357069143439 AND Hallways <= 0.0769230769230769 AND Main apartments <= 0.6666666666666666 AND exchanges_JOEY_CHANDLER <= 31.66666666666663 -> coverage=123, target_stat=8.3146, score=0.0752
#
#
# IF Central Perk > 0.05366357069143439 AND Hallways <= 0.0769230769230769 AND emotion_anger <= 0.07928996565752607 AND exchanges_JOEY_CHANDLER <= 31.66666666666663 -> coverage=100, target_stat=8.2820, score=0.0750
#
#
# IF Central Perk > 0.05366357069143439 AND Hallways <= 0.0769230769230769 AND avg_words_per_line > 9.118298996014051 AND exchanges_JOEY_CHANDLER <= 31.66666666666663 -> coverage=118, target_stat=8.3119, score=0.0735
#
#
# IF Central Perk > 0.05366357069143439 AND emotion_anger <= 0.07928996565752607 AND emotion_disgust > 0.03558859298178982 -> coverage=106, target_stat=8.2962, score=0.0731
#
#
# IF Central Perk > 0.05366357069143439 AND Hallways <= 0.0769230769230769 AND emotion_anger <= 0.09343565798345005 AND exchanges_JOEY_CHANDLER <= 31.66666666666663 -> coverage=121, target_stat=8.3165, score=0.0730
#
#
# IF Central Perk > 0.05366357069143439 AND Hallways <= 0.0769230769230769 AND avg_words_per_line > 9.118298996014051 AND emotion_anger <= 0.09343565798345005 -> coverage=119, target_stat=8.3151, score=0.0725
#
#
# IF Central Perk > 0.05366357069143439 AND Main apartments <= 0.6666666666666666 AND emotion_anger <= 0.09343565798345005 AND emotion_disgust > 0.03558859298178982 -> coverage=122, target_stat=8.3197, score=0.0720
#
#
# IF Central Perk > 0.05366357069143439 AND Hallways <= 0.0769230769230769 AND Main apartments <= 0.6666666666666666 AND emotion_anger <= 0.09343565798345005 -> coverage=127, target_stat=8.3260, score=0.0715
#
#
# IF Central Perk > 0.05366357069143439 AND Hallways <= 0.0 AND Main apartments <= 0.6666666666666666 AND exchanges_JOEY_CHANDLER <= 31.66666666666663 -> coverage=106, target_stat=8.3000, score=0.0714
#
#
# IF Central Perk > 0.1176470588235294 AND emotion_anger <= 0.09343565798345005 AND exchanges_PHOEBE_JOEY <= 16.0 -> coverage=106, target_stat=8.3009, score=0.0709
#
#
# IF Central Perk > 0.05366357069143439 AND Main apartments <= 0.6666666666666666 AND emotion_anger <= 0.07928996565752607 AND emotion_disgust > 0.03558859298178982 -> coverage=97, target_stat=8.2866, score=0.0708
#
#
# IF Central Perk > 0.05366357069143439 AND Hallways <= 0.0769230769230769 AND avg_words_per_line > 9.118298996014051 -> coverage=141, target_stat=8.3404, score=0.0708
#
#
# IF Central Perk <= 0.27693602693602687 AND avg_words_per_line <= 10.535767234093926 AND exchanges_MONICA_CHANDLER > 4.0 AND humor <= 0.6980063008416796 -> coverage=97, target_stat=8.6309, score=0.0707
#
#
# IF Central Perk > 0.05366357069143439 AND avg_words_per_line > 9.118298996014051 AND emotion_anger <= 0.09343565798345005 AND emotion_disgust > 0.03558859298178982 -> coverage=115, target_stat=8.3139, score=0.0706
#
#
# IF Central Perk <= 0.1666666666666666 AND avg_words_per_line <= 11.092173966459857 AND character_lines_JOEY <= 0.17570084246347942 AND exchanges_MONICA_CHANDLER > 4.0 -> coverage=69, target_stat=8.7000, score=0.0705

# %% [markdown]
# ## Scored by mean difference without coverage

# %%
sd = SubgroupDiscovery(beam_width=500, max_depth=4, min_support=0.05, numeric_thresholds=5, scoring="mean_diff", target_type="continuous", verbose=True)
top = sd.fit(df[descriptors_and_target], target="stars", top_k=15)
# Out:
# n_total=236, global_stat=8.458898305084746, min_sup_count=12

# %%
for s in top:
    print(s)
    print("\n")
# Out:
# IF Central Perk <= 0.1176470588235294 AND avg_words_per_line <= 9.118298996014051 AND character_lines_JOEY <= 0.17570084246347942 AND character_lines_OTHER <= 0.15568986413216815 -> coverage=12, target_stat=9.1167, score=0.6578
#
#
# IF Central Perk <= 0.1176470588235294 AND avg_words_per_line <= 9.118298996014051 AND character_lines_CHANDLER > 0.09835132045657033 AND emotion_disgust <= 0.053389852674700124 -> coverage=12, target_stat=9.1083, score=0.6494
#
#
# IF Central Perk <= 0.1176470588235294 AND avg_words_per_line <= 9.118298996014051 AND character_lines_OTHER <= 0.15568986413216815 AND sentiment_neu <= 0.8080949199167747 -> coverage=12, target_stat=9.0917, score=0.6328
#
#
# IF Central Perk <= 0.1176470588235294 AND avg_words_per_line <= 9.118298996014051 AND character_lines_OTHER <= 0.15568986413216815 AND exchanges_ROSS_RACHEL <= 45.833333333333314 -> coverage=12, target_stat=9.0917, score=0.6328
#
#
# IF Central Perk <= 0.1176470588235294 AND avg_words_per_line <= 9.118298996014051 AND character_lines_OTHER <= 0.15568986413216815 AND exchanges_MONICA_CHANDLER > 4.0 -> coverage=12, target_stat=9.0917, score=0.6328
#
#
# IF Central Perk <= 0.1176470588235294 AND Jobs <= 0.2307692307692307 AND avg_words_per_line <= 9.118298996014051 AND character_lines_OTHER <= 0.15568986413216815 -> coverage=12, target_stat=9.0917, score=0.6328
#
#
# IF Central Perk <= 0.1176470588235294 AND avg_words_per_line <= 9.118298996014051 AND character_lines_OTHER <= 0.19171680962744844 AND exchanges_MONICA_CHANDLER > 4.0 -> coverage=12, target_stat=9.0917, score=0.6328
#
#
# IF Central Perk <= 0.1176470588235294 AND avg_words_per_line <= 9.118298996014051 AND character_lines_OTHER <= 0.24274108748007187 AND exchanges_MONICA_CHANDLER > 4.0 -> coverage=12, target_stat=9.0917, score=0.6328
#
#
# IF Central Perk <= 0.1176470588235294 AND avg_words_per_line <= 9.118298996014051 AND character_lines_RACHEL > 0.10597595120243987 AND exchanges_ROSS_RACHEL > 12.0 -> coverage=12, target_stat=9.0833, score=0.6244
#
#
# IF Central Perk <= 0.1176470588235294 AND avg_words_per_line <= 9.118298996014051 AND character_lines_RACHEL > 0.10597595120243987 AND exchanges_PHOEBE_JOEY > 1.0 -> coverage=12, target_stat=9.0833, score=0.6244
#
#
# IF Central Perk <= 0.1176470588235294 AND avg_words_per_line <= 9.118298996014051 AND character_lines_RACHEL > 0.10597595120243987 AND humor <= 0.6556834219954402 -> coverage=12, target_stat=9.0833, score=0.6244
#
#
# IF Central Perk <= 0.1176470588235294 AND avg_words_per_line <= 9.118298996014051 AND character_lines_RACHEL > 0.10597595120243987 AND humor <= 0.6716174031801776 -> coverage=12, target_stat=9.0833, score=0.6244
#
#
# IF Central Perk <= 0.1176470588235294 AND avg_words_per_line <= 9.118298996014051 AND character_lines_OTHER <= 0.15568986413216815 -> coverage=13, target_stat=9.0769, score=0.6180
#
#
# IF Central Perk <= 0.1176470588235294 AND avg_words_per_line <= 9.118298996014051 AND character_lines_OTHER <= 0.15568986413216815 AND character_lines_ROSS > 0.10338481162589404 -> coverage=13, target_stat=9.0769, score=0.6180
#
#
# IF Central Perk <= 0.1176470588235294 AND avg_words_per_line <= 9.118298996014051 AND character_lines_OTHER <= 0.15568986413216815 AND emotion_disgust <= 0.053389852674700124 -> coverage=13, target_stat=9.0769, score=0.6180
